# %%
import lightning as L
import torch

# %%
class KeypointTransformer():
    def __init__(self, feature_len: int, d_model: int):
        pass

# %%
class LitKeypointTransformer(L.LightningModule):
    def __init__(self):
        pass
